# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor 
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer

# %%
# import dataset
car_sales = pd.read_csv("../../dataset/car-sales-extended-missing-data.csv")

# %%
car_sales.isna().sum()
# Out:
# Make             49
# Colour           50
# Odometer (KM)    50
# Doors            50
# Price            50
# dtype: int64

# %%
car_sales.dropna(subset=['Price'], inplace=True)

# %%
car_sales.isna().sum()
# Out:
# Make             47
# Colour           46
# Odometer (KM)    48
# Doors            47
# Price             0
# dtype: int64

# %%
len(car_sales)
# Out:
# 950

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 950 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           903 non-null    object
#  1   Colour         904 non-null    object
#  2   Odometer (KM)  902 non-null    float64
#  3   Doors          903 non-null    float64
#  4   Price          950 non-null    float64
# dtypes: float64(3), object(2)
# memory usage: 44.5+ KB

# %%
car_sales['Doors'].value_counts()
# Out:
# Doors
# 4.0    768
# 5.0     71
# 3.0     64
# Name: count, dtype: int64

# %%
car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [950 rows x 5 columns]

# %%
# Setup random seed
np.random.seed(42)

# Define different feature and different transformer
categorycal_feature = ["Make", "Colour"]
categorical_transformer = Pipeline(steps=[
                        ("imputer", SimpleImputer(strategy="constant", fill_value="missing")),
                        ("oneHot", OneHotEncoder(handle_unknown="ignore"))
                        ])

door_feature = ["Doors"]
door_transformer = Pipeline(steps=[
                        ("impute", SimpleImputer(strategy="constant", fill_value=4))
                        ])

numeric_feature = ['Odometer (KM)']
numeric_transformer = Pipeline(steps=[
                        ("imputer", SimpleImputer(strategy="mean"))  
                        ])

# setup perprocessing setp for missing value and turn category into number
preprocessor = ColumnTransformer([
                            ("category", categorical_transformer, categorycal_feature),
                            ("door", door_transformer, door_feature),
                            ("number", numeric_transformer, numeric_feature)
                            ])

# create preprocessing and modeling pipeline
model = Pipeline(steps=[
                ("preprocessing", preprocessor), 
                ("model", RandomForestRegressor())    
                ])

# Create X, y
X = car_sales.drop('Price', axis=1)
y = car_sales['Price']

# Split dataset into train and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.22188417408787875

# %%
model.get_params()
# Out:
# {'memory': None,
#  'steps': [('preprocessing',
#    ColumnTransformer(transformers=[('category',
#                                     Pipeline(steps=[('imputer',
#                                                      SimpleImputer(fill_value='missing',
#                                                                    strategy='constant')),
#                                                     ('oneHot',
#                                                      OneHotEncoder(handle_unknown='ignore'))]),
#                                     ['Make', 'Colour']),
#                                    ('door',
#                                     Pipeline(steps=[('impute',
#                                                      SimpleImputer(fill_value=4,
#                                                                    strategy='constant'))]),
#                                     ['Doors']),
#                                    ('number',
#                                     Pipeline(steps=[('imputer', SimpleImputer())]),
#                                     ['Odometer (KM)'])])),
#   ('model', RandomForestRegressor())],
#  'verbose': False,
#  'preprocessing': ColumnTransformer(transformers=[('category',
#                                   Pipeline(steps=[('imputer',
#                                                    SimpleImputer(fill_value='missing',
#                                                                  strategy='constant')),
#                                                   ('oneHot',
#                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                   ['Make', 'Colour']),
#                                  ('door',
#                                   Pipeline(steps=[('impute',
#                                                    SimpleImputer(fill_value=4,
#                                                                  strategy='constant'))]),
#                                   ['Doors']),
#                                  ('number',
#                                   Pipeline(steps=[('imputer', SimpleImputer())]),
#                                   ['Odometer (KM)'])]),
#  'model': RandomForestRegressor(),
#  'preprocessing__n_jobs': None,
#  'preprocessing__remainder': 'drop',
#  'preprocessing__sparse_threshold': 0.3,
#  'preprocessing__transformer_weights': None,
#  'preprocessing__transformers': [('category',
#    Pipeline(steps=[('imputer',
#                     SimpleImputer(fill_value='missing', strategy='constant')),
#                    ('oneHot', OneHotEncoder(handle_unknown='ignore'))]),
#    ['Make', 'Colour']),
#   ('door',
#    Pipeline(steps=[('impute', SimpleImputer(fill_value=4, strategy='constant'))]),
#    ['Doors']),
#   ('number',
#    Pipeline(steps=[('imputer', SimpleImputer())]),
#    ['Odometer (KM)'])],
#  'preprocessing__verbose': False,
#  'preprocessing__verbose_feature_names_out': True,
#  'preprocessing__category': Pipeline(steps=[('imputer',
#                   SimpleImputer(fill_value='missing', strategy='constant')),
#                  ('oneHot', OneHotEncoder(handle_unknown='ignore'))]),
#  'preprocessing__door': Pipeline(steps=[('impute', SimpleImputer(fill_value=4, strategy='constant'))]),
#  'preprocessing__number': Pipeline(steps=[('imputer', SimpleImputer())]),
#  'preprocessing__category__memory': None,
#  'preprocessing__category__steps': [('imputer',
#    SimpleImputer(fill_value='missing', strategy='constant')),
#   ('oneHot', OneHotEncoder(handle_unknown='ignore'))],
#  'preprocessing__category__verbose': False,
#  'preprocessing__category__imputer': SimpleImputer(fill_value='missing', strategy='constant'),
#  'preprocessing__category__oneHot': OneHotEncoder(handle_unknown='ignore'),
#  'preprocessing__category__imputer__add_indicator': False,
#  'preprocessing__category__imputer__copy': True,
#  'preprocessing__category__imputer__fill_value': 'missing',
#  'preprocessing__category__imputer__keep_empty_features': False,
#  'preprocessing__category__imputer__missing_values': nan,
#  'preprocessing__category__imputer__strategy': 'constant',
#  'preprocessing__category__oneHot__categories': 'auto',
#  'preprocessing__category__oneHot__drop': None,
#  'preprocessing__category__oneHot__dtype': numpy.float64,
#  'preprocessing__category__oneHot__feature_name_combiner': 'concat',
#  'preprocessing__category__oneHot__handle_unknown': 'ignore',
#  'preprocessing__category__oneHot__max_categories': None,
#  'preprocessing__category__oneHot__min_frequency': None,
#  'preprocessing__category__oneHot__sparse_output': True,
#  'preprocessing__door__memory': None,
#  'preprocessing__door__steps': [('impute',
#    SimpleImputer(fill_value=4, strategy='constant'))],
#  'preprocessing__door__verbose': False,
#  'preprocessing__door__impute': SimpleImputer(fill_value=4, strategy='constant'),
#  'preprocessing__door__impute__add_indicator': False,
#  'preprocessing__door__impute__copy': True,
#  'preprocessing__door__impute__fill_value': 4,
#  'preprocessing__door__impute__keep_empty_features': False,
#  'preprocessing__door__impute__missing_values': nan,
#  'preprocessing__door__impute__strategy': 'constant',
#  'preprocessing__number__memory': None,
#  'preprocessing__number__steps': [('imputer', SimpleImputer())],
#  'preprocessing__number__verbose': False,
#  'preprocessing__number__imputer': SimpleImputer(),
#  'preprocessing__number__imputer__add_indicator': False,
#  'preprocessing__number__imputer__copy': True,
#  'preprocessing__number__imputer__fill_value': None,
#  'preprocessing__number__imputer__keep_empty_features': False,
#  'preprocessing__number__imputer__missing_values': nan,
#  'preprocessing__number__imputer__strategy': 'mean',
#  'model__bootstrap': True,
#  'model__ccp_alpha': 0.0,
#  'model__criterion': 'squared_error',
#  'model__max_depth': None,
#  'model__max_features': 1.0,
#  'model__max_leaf_nodes': None,
#  'model__max_samples': None,
#  'model__min_impurity_decrease': 0.0,
#  'model__min_samples_leaf': 1,
#  'model__min_samples_split': 2,
#  'model__min_weight_fraction_leaf': 0.0,
#  'model__monotonic_cst': None,
#  'model__n_estimators': 100,
#  'model__n_jobs': None,
#  'model__oob_score': False,
#  'model__random_state': None,
#  'model__verbose': 0,
#  'model__warm_start': False}

# %%
# Improve the model with GridSearchCV

para_grid = {
    'preprocessing__number__imputer__strategy': ['mean', 'median'],
    'model__n_estimators': [100, 1000],
    'model__max_depth': [None, 5],
    'model__max_features': ["sqrt", "log2"],
    'model__min_samples_split': [2, 4], 
    'model__min_samples_leaf': [1, 2] 
}

gs_model = GridSearchCV(model, para_grid, cv=5, verbose=2)

gs_model.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 64 candidates, totalling 320 fits
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.1s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.1s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.1s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.1s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.1s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.1s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.1s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.1s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.1s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.1s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   1.5s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   1.5s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   1.4s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   1.5s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   1.5s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   1.4s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   1.4s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   1.5s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   1.5s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   1.5s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.1s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.1s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.1s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   1.3s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   1.3s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   1.2s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   1.2s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   1.2s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   1.2s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   1.2s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   1.2s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   1.2s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   1.2s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   1.1s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   1.1s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   1.1s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   1.1s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   1.1s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   1.1s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   1.1s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   1.1s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   1.1s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   1.1s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   1.1s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   1.1s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   1.1s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   1.1s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   1.1s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   1.1s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   1.1s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   1.1s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   1.1s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   1.1s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.1s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.1s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.1s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.1s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.1s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.1s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.1s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.1s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.1s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.1s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   1.4s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   1.4s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   1.4s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   1.4s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   1.4s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   1.4s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   1.4s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   1.4s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   1.3s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   1.4s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.1s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   1.2s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   1.2s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   1.2s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   1.2s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   1.2s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   1.2s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   1.2s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   1.2s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   1.2s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   1.2s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   1.1s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   1.1s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   1.1s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   1.1s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   1.1s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   1.1s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   1.1s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   1.1s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   1.1s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   1.1s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   1.1s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   1.2s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   1.2s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   1.1s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   1.1s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   1.1s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   1.1s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   1.1s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   1.1s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   1.1s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   1.0s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   1.0s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   1.0s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   0.9s
# ...
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   1.0s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   0.9s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessing',
#                                         ColumnTransformer(transformers=[('category',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer(fill_value='missing',
#                                                                                                         strategy='constant')),
#                                                                                          ('oneHot',
#                                                                                           OneHotEncoder(handle_unknown='ignore'))]),
#                                                                          ['Make',
#                                                                           'Colour']),
#                                                                         ('door',
#                                                                          Pipeline(steps=[('impute',
#                                                                                           SimpleImputer(fill_value=4,
#                                                                                                         strategy='constant'))]),
#                                                                          ['Doo...
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer())]),
#                                                                          ['Odometer '
#                                                                           '(KM)'])])),
#                                        ('model', RandomForestRegressor())]),
#              param_grid={'model__max_depth': [None, 5],
#                          'model__max_features': ['sqrt', 'log2'],
#                          'model__min_samples_leaf': [1, 2],
#                          'model__min_samples_split': [2, 4],
#                          'model__n_estimators': [100, 1000],
#                          'preprocessing__number__imputer__strategy': ['mean',
#                                                                       'median']},
#              verbose=2)

# %%
gs_model.score(X_test, y_test)
# Out:
# 0.28090562243779293

# %%
# Improve the model with RandomizedSearchCV

param_distributions = {
    'preprocessing__number__imputer__strategy': ['mean', 'median'],
    'model__n_estimators': [100, 1000],
    'model__max_depth': [None, 5],
    'model__max_features': ["sqrt", "log2"],
    'model__min_samples_split': [2, 4], 
    'model__min_samples_leaf': [1, 2] 
}

rs_model = RandomizedSearchCV(model, param_distributions, n_iter=10, cv=5, verbose=2)

rs_model.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   1.1s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   1.1s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   1.1s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   1.1s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   1.1s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=1000, preprocessing__number__imputer__strategy=mean; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=1000, preprocessing__number__imputer__strategy=median; total time=   0.9s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessing__number__imputer__strategy=mean; total time=   0.1s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.1s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.1s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.1s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.1s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessing__number__imputer__strategy=median; total time=   0.1s
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('preprocessing',
#                                               ColumnTransformer(transformers=[('category',
#                                                                                Pipeline(steps=[('imputer',
#                                                                                                 SimpleImputer(fill_value='missing',
#                                                                                                               strategy='constant')),
#                                                                                                ('oneHot',
#                                                                                                 OneHotEncoder(handle_unknown='ignore'))]),
#                                                                                ['Make',
#                                                                                 'Colour']),
#                                                                               ('door',
#                                                                                Pipeline(steps=[('impute',
#                                                                                                 SimpleImputer(fill_value=4,
#                                                                                                               strategy='constant'))])...
#                                                                                Pipeline(steps=[('imputer',
#                                                                                                 SimpleImputer())]),
#                                                                                ['Odometer '
#                                                                                 '(KM)'])])),
#                                              ('model',
#                                               RandomForestRegressor())]),
#                    param_distributions={'model__max_depth': [None, 5],
#                                         'model__max_features': ['sqrt', 'log2'],
#                                         'model__min_samples_leaf': [1, 2],
#                                         'model__min_samples_split': [2, 4],
#                                         'model__n_estimators': [100, 1000],
#                                         'preprocessing__number__imputer__strategy': ['mean',
#                                                                                      'median']},
#                    verbose=2)

# %%
rs_model.score(X_test, y_test)
# Out:
# 0.2943857867241384

# %%
# Save file
from joblib import dump
dump(rs_model, "rs_car_sales_regression_model.joblib")
print("Model Save Successfully")
# Out:
# Model Save Successfully
