# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
nums = [1,2,3]
df = pd.Series(nums, index=["x", "y", "z"])
df
# Out:
# x    1
# y    2
# z    3
# dtype: int64

# %%
df['x']
# Out:
# 1

# %%
df['y']
# Out:
# 2

# %%
salary_dict = {"day1": 2000, "day2": 12300, "day3": 300}

salary_df = pd.Series(salary_dict)

salary_df
# Out:
# day1     2000
# day2    12300
# day3      300
# dtype: int64

# %%
data = {
    "Student Name": ["Jhon", "Smit", "Marry"],
    "Student ID" : [1001, 1002, 1003],
    "Student Age": [20, 25, 30]
}

student_df = pd.DataFrame(data)

student_df
# Out:
#   Student Name  Student ID  Student Age
# 0         Jhon        1001           20
# 1         Smit        1002           25
# 2        Marry        1003           30

# %%
name_series = ["Jhon", "Smit", "Marry"]
age_series = [20, 25, 30]
city_series = ['London', 'Dhaka', 'New York']
custom_index = ['x', 'y', 'z']
data = {
    "Student Name": name_series,
    "Student Age": age_series,
    "Student City": city_series
}
df = pd.DataFrame(data, index=custom_index)

df
# Out:
#   Student Name  Student Age Student City
# x         Jhon           20       London
# y         Smit           25        Dhaka
# z        Marry           30     New York

# %%
df.loc['x']
# Out:
# Student Name      Jhon
# Student Age         20
# Student City    London
# Name: x, dtype: object

# %%
df.loc[['x', 'y']]
# Out:
#   Student Name  Student Age Student City
# x         Jhon           20       London
# y         Smit           25        Dhaka

# %%
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

df = pd.DataFrame(data, index = ["day1", "day2", "day3"])

# %%
df
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45

# %%
car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales['Odometer (KM)']
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
car_sales.rename(columns={"Odometer (KM)": "odometer"}, inplace=True)

# %%
car_sales
# Out:
#      Make Colour  odometer  Doors       Price
# 0  Toyota  White    150043      4   $4,000.00
# 1   Honda    Red     87899      4   $5,000.00
# 2  Toyota   Blue     32549      3   $7,000.00
# 3     BMW  Black     11179      5  $22,000.00
# 4  Nissan  White    213095      4   $3,500.00
# 5  Toyota  Green     99213      4   $4,500.00
# 6   Honda   Blue     45698      4   $7,500.00
# 7   Honda   Blue     54738      4   $7,000.00
# 8  Toyota  White     60000      4   $6,250.00
# 9  Nissan  White     31600      4   $9,700.00

# %%
car_sales.rename(columns={"Make": "make", "Colour": "color", "Doors": "doors", "Price":"price"}, inplace=True)

# %%
car_sales
# Out:
#      make  color  odometer  doors       price
# 0  Toyota  White    150043      4   $4,000.00
# 1   Honda    Red     87899      4   $5,000.00
# 2  Toyota   Blue     32549      3   $7,000.00
# 3     BMW  Black     11179      5  $22,000.00
# 4  Nissan  White    213095      4   $3,500.00
# 5  Toyota  Green     99213      4   $4,500.00
# 6   Honda   Blue     45698      4   $7,500.00
# 7   Honda   Blue     54738      4   $7,000.00
# 8  Toyota  White     60000      4   $6,250.00
# 9  Nissan  White     31600      4   $9,700.00

# %%
car_sales_doors = car_sales['color'] == "White"

# %%
car_sales_doors
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# 6    False
# 7    False
# 8     True
# 9     True
# Name: color, dtype: bool

# %%
len(car_sales)
# Out:
# 10

# %%
car_sales = pd.read_csv("car-sales-missing-data.csv")
car_sales
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %% [markdown]
# car_sales

# %%
car_sales
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales.rename(columns={"Make": "make", "Colour": "color", "Odometer": "odometer", "Doors":"door", "Price": "price" }, inplace=True)

# %%
car_sales
# Out:
#      make  color  odometer  door    price
# 0  Toyota  White  150043.0   4.0   $4,000
# 1   Honda    Red   87899.0   4.0   $5,000
# 2  Toyota   Blue       NaN   3.0   $7,000
# 3     BMW  Black   11179.0   5.0  $22,000
# 4  Nissan  White  213095.0   4.0   $3,500
# 5  Toyota  Green       NaN   4.0   $4,500
# 6   Honda    NaN       NaN   4.0   $7,500
# 7   Honda   Blue       NaN   4.0      NaN
# 8  Toyota  White   60000.0   NaN      NaN
# 9     NaN  White   31600.0   4.0   $9,700

# %%
car_sales.head()
# Out:
#      make  color  odometer  door    price
# 0  Toyota  White  150043.0   4.0   $4,000
# 1   Honda    Red   87899.0   4.0   $5,000
# 2  Toyota   Blue       NaN   3.0   $7,000
# 3     BMW  Black   11179.0   5.0  $22,000
# 4  Nissan  White  213095.0   4.0   $3,500

# %%
car_sales.tail()
# Out:
#      make  color  odometer  door   price
# 5  Toyota  Green       NaN   4.0  $4,500
# 6   Honda    NaN       NaN   4.0  $7,500
# 7   Honda   Blue       NaN   4.0     NaN
# 8  Toyota  White   60000.0   NaN     NaN
# 9     NaN  White   31600.0   4.0  $9,700

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   make      9 non-null      object
#  1   color     9 non-null      object
#  2   odometer  6 non-null      float64
#  3   door      9 non-null      float64
#  4   price     8 non-null      object
# dtypes: float64(2), object(3)
# memory usage: 532.0+ bytes

# %%
new_df = car_sales.dropna()

# %%
new_df
# Out:
#      make  color  odometer  door    price
# 0  Toyota  White  150043.0   4.0   $4,000
# 1   Honda    Red   87899.0   4.0   $5,000
# 3     BMW  Black   11179.0   5.0  $22,000
# 4  Nissan  White  213095.0   4.0   $3,500

# %%
car_sales
# Out:
#      make  color  odometer  door    price
# 0  Toyota  White  150043.0   4.0   $4,000
# 1   Honda    Red   87899.0   4.0   $5,000
# 2  Toyota   Blue       NaN   3.0   $7,000
# 3     BMW  Black   11179.0   5.0  $22,000
# 4  Nissan  White  213095.0   4.0   $3,500
# 5  Toyota  Green       NaN   4.0   $4,500
# 6   Honda    NaN       NaN   4.0   $7,500
# 7   Honda   Blue       NaN   4.0      NaN
# 8  Toyota  White   60000.0   NaN      NaN
# 9     NaN  White   31600.0   4.0   $9,700

# %%
new_df = car_sales.fillna(120)
new_df
# Out:
#      make  color  odometer   door    price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue     120.0    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green     120.0    4.0   $4,500
# 6   Honda    120     120.0    4.0   $7,500
# 7   Honda   Blue     120.0    4.0      120
# 8  Toyota  White   60000.0  120.0      120
# 9     120  White   31600.0    4.0   $9,700

# %%
car_sales['price'] = car_sales['price'].str.replace(r'[$,]', '', regex=True)

# %%
car_sales.dtypes
# Out:
# make         object
# color        object
# odometer    float64
# door        float64
# price        object
# dtype: object

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.describe()
# Out:
#             odometer  door
# count       6.000000   9.0
# mean    92302.666667   4.0
# std     76489.805168   0.5
# min     11179.000000   3.0
# 25%     38700.000000   4.0
# 50%     73949.500000   4.0
# 75%    134507.000000   4.0
# max    213095.000000   5.0

# %%
car_sales
# Out:
#      make  color  odometer  door  price
# 0  Toyota  White  150043.0   4.0   4000
# 1   Honda    Red   87899.0   4.0   5000
# 2  Toyota   Blue       NaN   3.0   7000
# 3     BMW  Black   11179.0   5.0  22000
# 4  Nissan  White  213095.0   4.0   3500
# 5  Toyota  Green       NaN   4.0   4500
# 6   Honda    NaN       NaN   4.0   7500
# 7   Honda   Blue       NaN   4.0    NaN
# 8  Toyota  White   60000.0   NaN    NaN
# 9     NaN  White   31600.0   4.0   9700

# %%
car_sales['price'].dtypes
# Out:
# dtype('O')

# %%
car_sales['odometer'].sum()
# Out:
# 553816.0

# %%
car_sales['odometer'].mean()
# Out:
# 92302.66666666667

# %%
car_sales[ car_sales['color'] == 'White']
# Out:
#      make  color  odometer  door price
# 0  Toyota  White  150043.0   4.0  4000
# 4  Nissan  White  213095.0   4.0  3500
# 8  Toyota  White   60000.0   NaN   NaN
# 9     NaN  White   31600.0   4.0  9700

# %%
car_sales[car_sales['make'] == "Toyota" ]
# Out:
#      make  color  odometer  door price
# 0  Toyota  White  150043.0   4.0  4000
# 2  Toyota   Blue       NaN   3.0  7000
# 5  Toyota  Green       NaN   4.0  4500
# 8  Toyota  White   60000.0   NaN   NaN

# %%
car_sales[ car_sales['odometer'] > 100000 ]
# Out:
#      make  color  odometer  door price
# 0  Toyota  White  150043.0   4.0  4000
# 4  Nissan  White  213095.0   4.0  3500

# %%
car_sales
# Out:
#      make  color  odometer  door  price
# 0  Toyota  White  150043.0   4.0   4000
# 1   Honda    Red   87899.0   4.0   5000
# 2  Toyota   Blue       NaN   3.0   7000
# 3     BMW  Black   11179.0   5.0  22000
# 4  Nissan  White  213095.0   4.0   3500
# 5  Toyota  Green       NaN   4.0   4500
# 6   Honda    NaN       NaN   4.0   7500
# 7   Honda   Blue       NaN   4.0    NaN
# 8  Toyota  White   60000.0   NaN    NaN
# 9     NaN  White   31600.0   4.0   9700

# %%
car_sales['price'] = car_sales['price'].str.replace(r'[\$\,\.]', '', regex=True)

# %%
car_sales
# Out:
#      make  color  odometer  door  price
# 0  Toyota  White  150043.0   4.0   4000
# 1   Honda    Red   87899.0   4.0   5000
# 2  Toyota   Blue       NaN   3.0   7000
# 3     BMW  Black   11179.0   5.0  22000
# 4  Nissan  White  213095.0   4.0   3500
# 5  Toyota  Green       NaN   4.0   4500
# 6   Honda    NaN       NaN   4.0   7500
# 7   Honda   Blue       NaN   4.0    NaN
# 8  Toyota  White   60000.0   NaN    NaN
# 9     NaN  White   31600.0   4.0   9700

# %%
pd.crosstab(car_sales['make'] , car_sales['door'])
# Out:
# door    3.0  4.0  5.0
# make
# BMW       0    0    1
# Honda     0    3    0
# Nissan    0    1    0
# Toyota    1    2    0

# %%
car_sales.groupby('make').sum()
# Out:
#                       color  odometer  door         price
# make
# BMW                   Black   11179.0   5.0         22000
# Honda               RedBlue   87899.0  12.0      50007500
# Nissan                White  213095.0   4.0          3500
# Toyota  WhiteBlueGreenWhite  210043.0  11.0  400070004500

# %%
car_sales
# Out:
#      make  color  odometer  door  price
# 0  Toyota  White  150043.0   4.0   4000
# 1   Honda    Red   87899.0   4.0   5000
# 2  Toyota   Blue       NaN   3.0   7000
# 3     BMW  Black   11179.0   5.0  22000
# 4  Nissan  White  213095.0   4.0   3500
# 5  Toyota  Green       NaN   4.0   4500
# 6   Honda    NaN       NaN   4.0   7500
# 7   Honda   Blue       NaN   4.0    NaN
# 8  Toyota  White   60000.0   NaN    NaN
# 9     NaN  White   31600.0   4.0   9700

# %%
car_sales['odometer'].plot()
# Out:
# <Axes: >

# %%
new_df = car_sales.dropna()

# %%
new_df
# Out:
#      make  color  odometer  door  price
# 0  Toyota  White  150043.0   4.0   4000
# 1   Honda    Red   87899.0   4.0   5000
# 3     BMW  Black   11179.0   5.0  22000
# 4  Nissan  White  213095.0   4.0   3500

# %%
car_sales_fresh = pd.read_csv("car-sales.csv")
car_sales_fresh
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales_fresh.rename( columns={"Make": "make", "Colour": "color", "Odometer (KM)": "odometer", "Doors": "doors", "Price": "price"}, inplace=True )

# %%
car_sales_fresh
# Out:
#      make  color  odometer  doors       price
# 0  Toyota  White    150043      4   $4,000.00
# 1   Honda    Red     87899      4   $5,000.00
# 2  Toyota   Blue     32549      3   $7,000.00
# 3     BMW  Black     11179      5  $22,000.00
# 4  Nissan  White    213095      4   $3,500.00
# 5  Toyota  Green     99213      4   $4,500.00
# 6   Honda   Blue     45698      4   $7,500.00
# 7   Honda   Blue     54738      4   $7,000.00
# 8  Toyota  White     60000      4   $6,250.00
# 9  Nissan  White     31600      4   $9,700.00

# %%
plt.plot(car_sales_fresh['odometer'])

# %%
plt.hist(car_sales_fresh['odometer']);

# %%
car_sales_fresh['odometer'].hist();

# %%
car_sales_fresh['price'] = car_sales_fresh['price'].str.replace(r'[\$\,\.]', '', regex=True).astype(int)

# %%
car_sales_fresh
# Out:
#      make  color  odometer  doors    price
# 0  Toyota  White    150043      4   400000
# 1   Honda    Red     87899      4   500000
# 2  Toyota   Blue     32549      3   700000
# 3     BMW  Black     11179      5  2200000
# 4  Nissan  White    213095      4   350000
# 5  Toyota  Green     99213      4   450000
# 6   Honda   Blue     45698      4   750000
# 7   Honda   Blue     54738      4   700000
# 8  Toyota  White     60000      4   625000
# 9  Nissan  White     31600      4   970000

# %%
car_sales_fresh['price'].dtypes
# Out:
# dtype('int32')

# %%
car_sales_fresh['price'].hist()
# Out:
# <Axes: >

# %%
car_sales_fresh['price'].plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Manipulating Data

# %%
car_sales_fresh['make'].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: make, dtype: object

# %%
car_sales_fresh['make'] = car_sales_fresh['make'].str.lower()

# %%
car_sales_fresh
# Out:
#      make  color  odometer  doors    price
# 0  toyota  White    150043      4   400000
# 1   honda    Red     87899      4   500000
# 2  toyota   Blue     32549      3   700000
# 3     bmw  Black     11179      5  2200000
# 4  nissan  White    213095      4   350000
# 5  toyota  Green     99213      4   450000
# 6   honda   Blue     45698      4   750000
# 7   honda   Blue     54738      4   700000
# 8  toyota  White     60000      4   625000
# 9  nissan  White     31600      4   970000

# %%
car_sales_fresh['color'] =  car_sales_fresh['color'].str.lower()

# %%
car_sales_fresh
# Out:
#      make  color  odometer  doors    price
# 0  toyota  white    150043      4   400000
# 1   honda    red     87899      4   500000
# 2  toyota   blue     32549      3   700000
# 3     bmw  black     11179      5  2200000
# 4  nissan  white    213095      4   350000
# 5  toyota  green     99213      4   450000
# 6   honda   blue     45698      4   750000
# 7   honda   blue     54738      4   700000
# 8  toyota  white     60000      4   625000
# 9  nissan  white     31600      4   970000

# %%
car_sales_fresh.groupby('make').sum()
# Out:
#                       color  odometer  doors    price
# make
# bmw                   black     11179      5  2200000
# honda           redblueblue    188335     12  1950000
# nissan           whitewhite    244695      8  1320000
# toyota  whitebluegreenwhite    341805     15  2175000

# %%
car_sales_fresh
# Out:
#      make  color  odometer  doors    price
# 0  toyota  white    150043      4   400000
# 1   honda    red     87899      4   500000
# 2  toyota   blue     32549      3   700000
# 3     bmw  black     11179      5  2200000
# 4  nissan  white    213095      4   350000
# 5  toyota  green     99213      4   450000
# 6   honda   blue     45698      4   750000
# 7   honda   blue     54738      4   700000
# 8  toyota  white     60000      4   625000
# 9  nissan  white     31600      4   970000

# %%
car_sales
# Out:
#      make  color  odometer  door  price
# 0  Toyota  White  150043.0   4.0   4000
# 1   Honda    Red   87899.0   4.0   5000
# 2  Toyota   Blue       NaN   3.0   7000
# 3     BMW  Black   11179.0   5.0  22000
# 4  Nissan  White  213095.0   4.0   3500
# 5  Toyota  Green       NaN   4.0   4500
# 6   Honda    NaN       NaN   4.0   7500
# 7   Honda   Blue       NaN   4.0    NaN
# 8  Toyota  White   60000.0   NaN    NaN
# 9     NaN  White   31600.0   4.0   9700

# %%
x = car_sales['odometer'].mean()

car_sales['odometer'] = car_sales['odometer'].fillna(x)

# %%
car_sales
# Out:
#      make  color       odometer  door  price
# 0  Toyota  White  150043.000000   4.0   4000
# 1   Honda    Red   87899.000000   4.0   5000
# 2  Toyota   Blue   92302.666667   3.0   7000
# 3     BMW  Black   11179.000000   5.0  22000
# 4  Nissan  White  213095.000000   4.0   3500
# 5  Toyota  Green   92302.666667   4.0   4500
# 6   Honda    NaN   92302.666667   4.0   7500
# 7   Honda   Blue   92302.666667   4.0    NaN
# 8  Toyota  White   60000.000000   NaN    NaN
# 9     NaN  White   31600.000000   4.0   9700

# %%
seats_column = pd.Series([5,5,5,5,5,5,5])

car_sales['seat'] = seats_column

# %%
car_sales
# Out:
#      make  color       odometer  door  price  seat
# 0  Toyota  White  150043.000000   4.0   4000   5.0
# 1   Honda    Red   87899.000000   4.0   5000   5.0
# 2  Toyota   Blue   92302.666667   3.0   7000   5.0
# 3     BMW  Black   11179.000000   5.0  22000   5.0
# 4  Nissan  White  213095.000000   4.0   3500   5.0
# 5  Toyota  Green   92302.666667   4.0   4500   5.0
# 6   Honda    NaN   92302.666667   4.0   7500   5.0
# 7   Honda   Blue   92302.666667   4.0    NaN   NaN
# 8  Toyota  White   60000.000000   NaN    NaN   NaN
# 9     NaN  White   31600.000000   4.0   9700   NaN

# %%
car_sales['seat'] = car_sales['seat'].fillna(5)

# %%
car_sales
# Out:
#      make  color       odometer  door  price  seat
# 0  Toyota  White  150043.000000   4.0   4000   5.0
# 1   Honda    Red   87899.000000   4.0   5000   5.0
# 2  Toyota   Blue   92302.666667   3.0   7000   5.0
# 3     BMW  Black   11179.000000   5.0  22000   5.0
# 4  Nissan  White  213095.000000   4.0   3500   5.0
# 5  Toyota  Green   92302.666667   4.0   4500   5.0
# 6   Honda    NaN   92302.666667   4.0   7500   5.0
# 7   Honda   Blue   92302.666667   4.0    NaN   5.0
# 8  Toyota  White   60000.000000   NaN    NaN   5.0
# 9     NaN  White   31600.000000   4.0   9700   5.0

# %%
car_sales.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
car_sales.drop_duplicates()
# Out:
#      make  color       odometer  door  price  seat
# 0  Toyota  White  150043.000000   4.0   4000   5.0
# 1   Honda    Red   87899.000000   4.0   5000   5.0
# 2  Toyota   Blue   92302.666667   3.0   7000   5.0
# 3     BMW  Black   11179.000000   5.0  22000   5.0
# 4  Nissan  White  213095.000000   4.0   3500   5.0
# 5  Toyota  Green   92302.666667   4.0   4500   5.0
# 6   Honda    NaN   92302.666667   4.0   7500   5.0
# 7   Honda   Blue   92302.666667   4.0    NaN   5.0
# 8  Toyota  White   60000.000000   NaN    NaN   5.0
# 9     NaN  White   31600.000000   4.0   9700   5.0
